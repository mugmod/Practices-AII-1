# %% [markdown]
# Введите ваше ФИО:

# %%
Денисов Роман Николаевич

# %% [markdown]
# ***Дисклеймер***
#
# В данной практике запрещено использования функций:
#
#
# *   sum()
# *   min()
# *   max()
# *   average()
# *   reversed()
# *   sorted()
# *   готовые функции или библиотеки

# %% [markdown]
# **Задача 1:**
#
#
#
# Интернет-магазин предлагает следующие условия скидок:
#
# *   Для заказов больше 1000 единиц, клиент получает скидку 5%. Если клиент использует промокод SUPERDISCOUNT, он получает скидку 10% (вместо 5%).
# *  Для заказов более 5000 единиц, клиент получает скидку 15%, а использование промокода SUPERDISCOUNT увеличивает скидку до 20% (вместо 15%).
#
# Этап 1:
# Ввод:
# ```
# Введите стоимость единицы товара: 5
# Введите количество товара: 1001
# Введите промокод: GiVEMEDISCONT
# ```
#
# Вывод:
#
# ```
# Ваша скидка: 5%
# Итоговая сумма: 4754.75
# ```
# Этап 2:
#
# Оформите ваш код в виде функции

# %%
cost = int(input("Введите стоимость единицы товара: "))
quan = int(input("Введите колличество товара: "))
quan_end = cost * quan
if 5001 > quan > 1000:
  print("Ваша скидка: 5%")
  promo = input("У вас есть промокод?: да/нет ")
  if promo == "да":
    flag = True
    while flag:
      code = input("Введите промокод: ")
      if code == "SUPERDISCOUNT":
        print("Промокод применён. Ваша скидка увеличилась с 5% до 10%")
        proc_1 = quan_end / 100
        quantity = quan_end - (proc_1 * 10)
        print("Итоговая сумма:", quantity)
        break
      else:
        print("Такого промокода нет")
      flag = True if input('Хотите ввести ещё раз?(да/нет)') == 'да' else False
      if flag == False:
        print("Ваша скидка: 5%")
        proc_1 = quan_end / 100
        quantity = quan_end - (proc_1 * 5)
        print("Итоговая сумма:", quantity)
  if promo == "нет":
    print("Ваша скидка: 5%")
    proc_1 = quan_end / 100
    quantity = quan_end - (proc_1 * 5)
    print("Итоговая сумма:", quantity)
if quan > 5000:
  print("Ваша скидка: 15%")
  promo = input("У вас есть промокод?: да/нет ")
  if promo == "да":
    flag = True
    while flag:
      code = input("Введите промокод: ")
      if code == "SUPERDISCOUNT":
        print("Промокод применён. Ваша скидка увеличилась с 15% до 20%")
        proc_1 = quan_end / 100
        quantity = quan_end - (proc_1 * 20)
        print("Итоговая сумма:", quantity)
        break
      else:
        print("Такого промокода нет")
      flag = True if input('Хотите ввести ещё раз?(да/нет)') == 'да' else False
      if flag == False:
        print("Ваша скидка: 15%")
        proc_1 = quan_end / 100
        quantity = quan_end - (proc_1 * 15)
        print("Итоговая сумма:", quantity)
  if promo == "нет":
    print("Ваша скидка: 15%")
    proc_1 = quan_end / 100
    quantity = quan_end - (proc_1 * 15)
    print("Итоговая сумма:", quantity)

# %% [markdown]
# **Задача 2:**
#
# Этап 1:
# Напишите программу способную отфильтровать список и вывести только положительные элементы
#
#
# Ввод:
# ```
# -1 5 1 2 -3
# ```
#
# Вывод:
#
# ```
# 5 1 2
# ```
#
# Этап 2:
#
# Оформите ваш код в виде функции

# %%
numbers = [int(num) for num in input("Введите список чисел через пробел ").split()]
sec = []
for x in numbers:
  if x > 0:
    sec.append(x)
print(*sec)

# %% [markdown]
# **Задача 3:**
#
# Этап 1:
# Напишите программу реализующую Алгоритм Евклида
#
#
# > Алгоритм Евклида – это алгоритм нахождения наибольшего общего делителя (НОД) пары целых чисел.
#
#
#
# Ввод:
# ```
# 30 18
# ```
#
# Вывод:
#
# ```
# 6
# ```
#
# Этап 2:
# Оформите ваш код в виде функции

# %%
numbers = [int(num) for num in input("Введите чисела через пробел ").split()]
if numbers[0] >= numbers[1]:
  maximum = numbers[0]
  minimum = numbers[1]
else:
  maximum = numbers[1]
  minimum = numbers[0]
numer = 0
for x in range(1, minimum + 1):
  if minimum % x == 0 and maximum % x == 0:
    num = x
print(num)

# %% [markdown]
# **Задача 4:**
#
# Этап 1:
# Напишите функцию программу, которая принимает строку и возвращает список слов и количество их упомнинаний в предложении
#
# Этап 2:
# Оформите ваш код в виде функции
#
# Ввод:
# ```
# apple banana apple
# ```
#
# Вывод:
#
# ```
# apple: 2,
# banana: 1
# ```

# %%
name = [num for num in input("Введите фразу пробел ").split()]
name_end = []
for x in name:
  if name_end.count(x) == 0:
    name_end.append(x)
numbers = 0
for j in name_end:
  numbers += 1
for i in range(numbers):
    print(name_end[i], "=", name.count(name_end[i]))

# %% [markdown]
# **Задача 5:**
#
# Этап 1:
# Детектор анаграмм Напишите программу на Python, которая принимает в качестве входных данных две строки и проверяет, являются ли они анаграммами друг друга
#
# Этап 2:
# Оформите ваш код в виде функции
#
# Ввод:
# ```
# listen, silent
# ```
#
# Вывод:
#
# ```
# True
# ```

# %%
def F(a,b):
  if a == b[::-1]:
    return True
  return False
name = input("Введите слова ").split(", ")
print(F(name[0], name[1]))

# %% [markdown]
# **Задача 6:**
#
# Шифр ​​Цезаря
#
# Напишите программу на Python, которая реализует шифр Цезаря, простой метод шифрования, который заменяет каждую букву буквой на фиксированное количество позиций вниз по алфавиту. Программа должна запрашивать у пользователя сообщение и значение сдвига, а затем шифровать и расшифровывать сообщение.
#
# Этап 1:
#
# Напишите код для реализации данной задачи
#
# Этап 2:
#
# Оформите код в виде нескольких функций:
#
# * Зашифровывает сообщение
# * Расшифровывает сообщение

# %%
def encryption():
  name_old = input('Введите сообщение: ')
  shift = int(input('Введите значение сдвига: '))
  name_new = ' '

  for x in name_old:
    if x != ' ':
      name_new += alphabet[alphabet.index(x) + shift]

    else: name_new += ' '

  return name_new


def decoding():
  name_old = input('Введите сообщение: ')
  shift = int(input('Введите значение сдвига: '))
  name_new = ''

  for x in name_old:
    if x != ' ':
      name_new += alphabet[alphabet.index(x) - shift]

    else: name_new += ' '

  return name_new



alphabet = ['а', 'б', 'в', 'г', 'д', 'е', 'ё', 'ж', 'з', 'и',
            'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т',
            'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь',
            'э', 'ю', 'я']

while True:
  print('0 - завершить')
  print('1 - зашифровать')
  print('2 - расшифровать')
  entry = input('Ввод: ')

  if entry == '0': break
  if entry == '1': print(encryption())
  if entry == '2': print(decoding())
# Out:
# 0 - завершить
# 1 - зашифровать
# 2 - расшифровать
#  эдвэдвэвдэд
# 0 - завершить
# 1 - зашифровать
# 2 - расшифровать

# %% [markdown]
# **Задача 7**
#
# Задача: «Банковская система»
#
# Создайте программу Python, которая имитирует базовую банковскую систему. Система должна иметь следующие функции:
#
# Требования
# *   Система должна позволять клиентам создавать счета и хранить их балансы.
# *   Система должна позволять клиентам вносить и снимать деньги со своих счетов.
# *   Система должна позволять клиентам проверять свой текущий баланс.
# *   Система должна позволять клиентам переводить деньги между счетами.
# *   Система должна отслеживать транзакции (депозиты, снятия и переводы) и иметь возможность печатать детали транзакций.
#
#
# Задачи
# 1. Реализуйте банковскую систему, используя только базовые конструкции Python, такие как def, lists, if, elif и else, без классов или словарей.
# Определите функции для создания счетов, внесения и снятия денег, получения балансов счетов, перевода денег между счетами, а также создания и печати транзакций.
# 2. Напишите основную функцию, которая демонстрирует использование банковской системы путем создания счетов, внесения и снятия денег и перевода денег между счетами.
# 3. Бонусное задание
# Реализуйте способ хранения и печати истории транзакций для каждого счета.
#
# Ограничения
# Не используйте классы или словари.
# Используйте только базовые конструкции Python, такие как def, lists, if, elif и else.

# %%
base = []
schet = 'Счет не выбран'
def main():
  global schet
  while True:
    print('Выбран счет:', schet)
    print(' ')
    print('. - завершить программу')
    print('0 - выбрать счет')
    print('1 - создать счет')
    print('2 - посмотреть баланс')
    print('3 - внести деньги')
    print('4 - снять деньги')
    print('5 - перевести деньги')
    print('6 - список счетов')
    print(' ')

    entry = input('Ввод: ')

    if entry == '.': break

    if entry == '1':

      name = input('Введите имя счета: ')
      base.append(name)
      base.append(0)
      schet = base[base.index(name)]
      print('Счет успешно создан. Ваш баланс:', base[base.index(schet) + 1])

    if entry == '0':
      name = input('Введите название счёта: ')
      if name in base:
        schet = base[base.index(name)]
        print('Успешно')
      else: print('Счет не найден')

    if entry == '2':
      print('Ваш баланс:', base[base.index(schet) + 1])

    if entry == '3':
      takeaway = input('Сколько внести? Ввод: ')
      base[base.index(schet) + 1] += int(takeaway)
      print('Баланс пополнен. Сейчас на счету: ', base[base.index(schet) + 1])

    if entry ==  '4':
      takeaway = input('Сколько снять? Ввод: ')
      if int(takeaway) <= base[base.index(schet) + 1]:
        base[base.index(schet) + 1] -= int(takeaway)
        print('Успешно. Сейчас на счету: ', base[base.index(schet) + 1])
      else: print('На счете не хватает средств')

    if entry == '5':
      price_list = input('Введите название счета, на который необходимо совершить перевод: ')
      if price_list in base:
        price = int(input('Введите сумму: '))
        if base[base.index(schet) + 1] >= price:
          base[base.index(schet) + 1] -= price
          base[base.index(price_list) + 1] += price
          print('Перевод на сумму', str(price), 'выполнен')
        else: print('Недостаточно средств')
      else: print('Счет не найден')

    if entry == '6':
      print('Список счетов:')
      for i in range(0, len(base), 2):
        print(base[i])

main()
# Out:
# Выбран счет: Счет не выбран
#
# . - завершить программу
# 0 - выбрать счет
# 1 - создать счет
# 2 - посмотреть баланс
# 3 - внести деньги
# 4 - снять деньги
# 5 - перевести деньги
# 6 - список счетов
#
# Ввод: 0
# Введите название счёта: абоба
# Счет не найден
# Выбран счет: Счет не выбран
#
# . - завершить программу
# 0 - выбрать счет
# 1 - создать счет
# 2 - посмотреть баланс
# 3 - внести деньги
# 4 - снять деньги
# 5 - перевести деньги
# 6 - список счетов
#
# Ввод: 1
# Введите имя счета: абоба
# Счет успешно создан. Ваш баланс: 0
# Выбран счет: абоба
#
# . - завершить программу
# 0 - выбрать счет
# 1 - создать счет
# 2 - посмотреть баланс
# 3 - внести деньги
# 4 - снять деньги
# 5 - перевести деньги
# 6 - список счетов
#
# Ввод: 2
# Ваш баланс: 0
# Выбран счет: абоба
#
# . - завершить программу
# 0 - выбрать счет
# 1 - создать счет
# 2 - посмотреть баланс
# 3 - внести деньги
# 4 - снять деньги
# 5 - перевести деньги
# 6 - список счетов
#
# Ввод: 3
# Сколько внести? Ввод: 300
# ...
